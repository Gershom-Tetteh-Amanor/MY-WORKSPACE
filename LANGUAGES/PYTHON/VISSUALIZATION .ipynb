# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline
#%matplotlib inline

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5,5,1001)
fx = x**3 + 3*x**2 + 3*x + 1
fx2 = np.exp(-x**2)*np.sin(x) + np.cos(x)
plt.grid()

# %%
plt.plot(x,fx)

# %%
plt.plot(x,fx,color='gold')

# %%
plot(x,fx,color="#FF00FF")

# %%
plot(x,fx,color="#00FFBB", marker='o')

# %%
plot(x,fx,color='#ff00ff',marker='o',markerfacecolor='gold')

# %%
plot(x[::4],fx[::4],marker='o',markerfacecolor='none',color='none',markeredgecolor='k')

# %%
plot(x[::4],fx[::4],marker='o',markerfacecolor='none',markeredgecolor='k',color='none',markersize=5)

# %%
plot(x[::4],fx[::4],marker='o',markerfacecolor='none',markeredgecolor='gold',color='none',markersize=15)

# %%
plot(x,fx,linestyle=':',color='gold')

# %%
plot(x,fx,linestyle='-.',linewidth=2,color='orange')

# %%
plot(x,fx)
xlabel(r'$x$-axis')
ylabel(r'$y$-axis')
title('Plot of $x^3+3x^2+3x+1$')
# Out:
# Text(0.5, 1.0, 'Plot of $x^3+3x^2+3x+1$')

# %%
plot(x,fx)
xlabel(r'$x$ - axis')
ylabel(r'$y$ - axis')
title(r'Plot of $x^3 +3x^2 +3x+1$')
text(-1,0,'* root (-1,0)', color='gold', rotation =45,fontsize=12)
grid(True)

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-20,20,201)
y = np.sin(x)/x
# Invalid value because we have 0/0 which is indeterminate
print(x), print(y)
# Out:
# [-20.  -19.8 -19.6 -19.4 -19.2 -19.  -18.8 -18.6 -18.4 -18.2 -18.  -17.8
#  -17.6 -17.4 -17.2 -17.  -16.8 -16.6 -16.4 -16.2 -16.  -15.8 -15.6 -15.4
#  -15.2 -15.  -14.8 -14.6 -14.4 -14.2 -14.  -13.8 -13.6 -13.4 -13.2 -13.
#  -12.8 -12.6 -12.4 -12.2 -12.  -11.8 -11.6 -11.4 -11.2 -11.  -10.8 -10.6
#  -10.4 -10.2 -10.   -9.8  -9.6  -9.4  -9.2  -9.   -8.8  -8.6  -8.4  -8.2
#   -8.   -7.8  -7.6  -7.4  -7.2  -7.   -6.8  -6.6  -6.4  -6.2  -6.   -5.8
#   -5.6  -5.4  -5.2  -5.   -4.8  -4.6  -4.4  -4.2  -4.   -3.8  -3.6  -3.4
#   -3.2  -3.   -2.8  -2.6  -2.4  -2.2  -2.   -1.8  -1.6  -1.4  -1.2  -1.
#   -0.8  -0.6  -0.4  -0.2   0.    0.2   0.4   0.6   0.8   1.    1.2   1.4
#    1.6   1.8   2.    2.2   2.4   2.6   2.8   3.    3.2   3.4   3.6   3.8
#    4.    4.2   4.4   4.6   4.8   5.    5.2   5.4   5.6   5.8   6.    6.2
#    6.4   6.6   6.8   7.    7.2   7.4   7.6   7.8   8.    8.2   8.4   8.6
#    8.8   9.    9.2   9.4   9.6   9.8  10.   10.2  10.4  10.6  10.8  11.
# ...

# %%
plt.plot(x,y)

# %%
y2=y.copy()
y2
# Out:
# array([ 0.04564726,  0.04109463,  0.03479406,  0.02696215,  0.01788099,
#         0.00788827, -0.00263487, -0.01327815, -0.0236177 , -0.03323257,
#        -0.04172151, -0.04871922, -0.05391162, -0.05704939, -0.05795931,
#        -0.05655279, -0.05283137, -0.04688868, -0.03890894, -0.02916185,
#        -0.01799396, -0.00581689,  0.00690729,  0.01968301,  0.03199991,
#         0.04335252,  0.05326027,  0.06128707,  0.06705957,  0.07028357,
#         0.07075767,  0.06838374,  0.06317366,  0.05525193,  0.04485405,
#         0.03232054,  0.01808671,  0.0026685 , -0.01335518, -0.02936306,
#        -0.04471441, -0.05877331, -0.0709335 , -0.08064285, -0.08742658,
#        -0.0909082 , -0.09082743, -0.08705429, -0.0795987 , -0.06861517,
#        -0.05440211, -0.03739583, -0.01815904,  0.00263568,  0.02422716,
#         0.04579094,  0.06646786,  0.08539501,  0.10173797,  0.11472324,
#         0.12366978,  0.12801838,  0.12735785,  0.12144704,  0.11023165,
# ...

# %%
y2[x==0]=1
y2
# Making the discontinuity 1 since the limit as sin(x)/x approaches 0 is 1
# Out:
# array([ 0.04564726,  0.04109463,  0.03479406,  0.02696215,  0.01788099,
#         0.00788827, -0.00263487, -0.01327815, -0.0236177 , -0.03323257,
#        -0.04172151, -0.04871922, -0.05391162, -0.05704939, -0.05795931,
#        -0.05655279, -0.05283137, -0.04688868, -0.03890894, -0.02916185,
#        -0.01799396, -0.00581689,  0.00690729,  0.01968301,  0.03199991,
#         0.04335252,  0.05326027,  0.06128707,  0.06705957,  0.07028357,
#         0.07075767,  0.06838374,  0.06317366,  0.05525193,  0.04485405,
#         0.03232054,  0.01808671,  0.0026685 , -0.01335518, -0.02936306,
#        -0.04471441, -0.05877331, -0.0709335 , -0.08064285, -0.08742658,
#        -0.0909082 , -0.09082743, -0.08705429, -0.0795987 , -0.06861517,
#        -0.05440211, -0.03739583, -0.01815904,  0.00263568,  0.02422716,
#         0.04579094,  0.06646786,  0.08539501,  0.10173797,  0.11472324,
#         0.12366978,  0.12801838,  0.12735785,  0.12144704,  0.11023165,
# ...

# %%
plt.plot(x,y2)

# %%
plt.subplot(1,2,1) #number of plots on a graph
#plt.subplot(nrow,ncol,left=1,right=2)
plt.plot(x,y)
plt.subplot(1,2,2)
#plt.subplot(nrow,ncol,top=1,botomt=2)
plt.plot(x,y2)

# %%
plt.plot(x,y2,color=("#00ff00"))

# %%
plt.plot(x,y2,color=(153/255,102/255,204/255))

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle='--')

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle='-.')

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle=':')

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle=':',linewidth=15)

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle=':',linewidth=5,marker="v")

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle=':',linewidth=2,marker="o")

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle=':',linewidth=2,marker='.',markersize=3)

# %%
plt.plot(x,y2,color=("#00ff00"),linestyle='none',linewidth=5,marker=".")

# %%
plt.plot(y2) 
# The index position is being used as the independent variable
plt.title('A plot of the sine Function')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
text(100,1,'Turning point (100,1)', rotation = 45, color = 'gold')
# Out:
# Text(100, 1, 'Turning point (100,1)')

# %%
x2 = np.linspace(-4*np.pi,4*np.pi,201)
s1= np.sin(2*np.pi*x2)
s2 = np.sin(np.pi*x2)
s3 = np.sin(4*np.pi*x2)
plt.plot(x2,s1,label='sin(pi*x)')
plt.figure
plt.text(0,0.5,"3",fontsize=12,color='red')
plt.figure() #Extracts the figure
plt.plot(x2,s2,label='sin(2*pi*x)')
plt.figure()
plt.plot(x2,s3,label=('$\sin(4pi*x)$'))
plt.legend()
plt.text(0,0.5,"point(0,0.5)",fontsize=12,color='red',rotation=45)
# Out:
# Text(0, 0.5, 'point(0,0.5)')

# %% [markdown]
# ## 1D plotting:

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 3, 20)
y = np.linspace(0, 9, 20)
plt.plot(x, y) # line plot
plt.plot(x, y, 'o') # dot plot

# %% [markdown]
# ## 2D arrays (such as images):

# %%
image = np.random.rand(30, 30)
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()

# %% [markdown]
# ## Exercise: Simple visualizations
# • Plot some simple arrays: a cosine as a function of time and a 2D matrix.
#
# • Try using the gray colormap on the 2D matrix.

# %%
L = range(1000)

# %timeit [i**2 for i in L]


a = np.arange(1000)

# %timeit a**2
# Out:
# 315 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 1.07 µs ± 47.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.array(range(0, 10))
y = np.array([100, 23, 44, 12, 55, 85, 69, 33, 75, 2])
z = np.cos(x)
plt.title("Plotting 1-D array")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x, y, color = "gold", marker = "o", label = "Array elements")
plt.legend()
plt.show()

# %% [markdown]
# # ..............................................................................................................................

# %% [markdown]
# ## **********************************************************************************************************

# %% [markdown]
# # Copies and views
# A slicing operation creates a view on the original array, which is just a way of accessing array data.
# Thus the original array is not copied in memory. You can use np.may_share_memory() to check if two
# arrays share the same memory block. Note however, that this uses heuristics and may give you false
# positives.

# %%
a = np.arange(10)
a
b = a[::2]
b
np.may_share_memory(a,b)
b[0] = 12
b
np.may_share_memory(a,b)
# Out:
# True

# %%
a = np.arange(10)
a
c = a[::2].copy() # Force a copy
c[0] = 12 
c
np.may_share_memory(a,c)
# Out:
# False

# %% [markdown]
# # *******************************************************************************************

# %% [markdown]
# ## Worked example: Prime number sieve

# %% [markdown]
# ### Compute prime numbers in 0–99, with a sieve

# %%
# Construct a shape (100,) boolean array is_prime, filled with True in the beginning:
is_prime = np.ones((100,), dtype=bool)
# Cross out 0 and 1 which are not primes:
is_prime[:2] = 0
# For each integer j starting from 2, cross out its higher multiples:
N_max = int(np.sqrt(len(is_prime) - 1))
for j in range(2, N_max + 1):
    is_prime[2*j::j] = False
is_prime
# Out:
# array([False, False,  True,  True, False,  True, False,  True, False,
#        False, False,  True, False,  True, False, False, False,  True,
#        False,  True, False, False, False,  True, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False,  True, False, False, False,  True, False,  True, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False, False, False,  True, False,  True, False,
#        False, False, False, False,  True, False, False, False,  True,
#        False,  True, False, False, False, False, False,  True, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False])

# %%
isp = np.ones((100), dtype=bool)
isp[:2]=0
isp
int(np.sqrt(len(isp)-1))
# Out:
# 9

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(-2*pi,2*pi,1001)
fx1 = cos(x)
fx2 = sin(x)
fx3 = 0.5*(exp(-x**2)*sin(x) + cos(x))

# %%
plot(x,fx1,'r--',label=r'$\cos(x)$')
plot(x,fx2,'b-',label=r'$\sin(x)$')
plot(x,fx3,'k:',label=r'$0.5\left(e^{-x^2}\sin(x)+cos(x)\right)$')
legend(loc = 'best')

# %%
plot(x,fx1,'r--',label=r'$\cos(x)$')
plot(x,fx2,'b-',label=r'$\sin(x)$')
plot(x,fx3,'k:',label=r'$0.5\left(e^{-x^2}\sin(x)+cos(x)\right)$')
xlim(-8,20)
ylim(-1,1)
legend(loc = 'upper right')

# %%
plot(x,fx1,'r--',label=r'$\cos(x)$')
#cla()
plot(x,fx2,'b-',label=r'$\sin(x)$')
#clf()
plot(x,fx3,'k:',label=r'$0.5\left(e^{-x^2}\sin(x)+cos(x)\right)$')
xlim(-8,20)
ylim(-1,1)
legend(loc = 'upper right')

# %%
plot(x,fx1,'r--',label=r'$\cos(x)$')
figure()
plot(x,fx2,'b-',label=r'$\sin(x)$')
figure()
plot(x,fx3,'k:',label=r'$0.5\left(e^{-x^2}\sin(x)+cos(x)\right)$')
xlim(-8,20)
ylim(-1,1)
legend(loc = 'upper right')

# %%
plot(x,fx1,'r-',x,fx2,'b--',x,fx3,'k:')

# %%
plot(x,fx1,'r-',x,fx2,'b--',x,fx3,'k:');

# %%
b=plot(x,fx1,'r-',x,fx2,'b--',x,fx3,'k:')

# %%
subplot(2,2,1)
plot(x,fx1);
subplot(2,2,2)
plot(x,fx2);
subplot(2,2,3)
plot(x,fx3);
subplot(2,2,4)
plot(x,fx1,'r-',x,fx2,'b--',x,fx3,'k:');

# %%
fig = figure()
ax = fig.add_subplot(111)
plot(x,fx3);

# %%
# ?gca

# %%
a = 2+1j

# %%
a.real

# %%
plot(x,fx1,'r-',x,fx2,'b--',x,fx3,'g:')
legend('center right')
