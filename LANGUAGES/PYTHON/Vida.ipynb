# %% [markdown]
# # Rules for naming variables

# %%
2+3 # object
# Out:
# 5

# %%
a = 2 + 3

# %%
a
# Out:
# 5

# %%
RsbyTqF = 23
RsbyTqF
# Out:
# 23

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
a1 = 'bread'
a1
# Out:
# 'bread'

# %%
a_1 = 'brofoto'
a_1
# Out:
# 'brofoto'

# %%
a_ = 'togbe'
a_
# Out:
# 'togbe'

# %%
_a = 'gum'
_a
# Out:
# 'gum'

# %%
return = 1
# Out:
#   Cell In[17], line 1
#     return = 1
#            ^
# SyntaxError: invalid syntax

# %%
print = 1
print
# Out:
# 1

# %% [markdown]
# # Data types

# %%
sum(2,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sum(2,4)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# ### Numeric

# %% [markdown]
# #### integers

# %%
myint = 12
myint
type(myint)
# Out:
# int

# %%
myint2 = int(22.5)
myint2
type(myint2)
# Out:
# int

# %% [markdown]
# #### float

# %%
myfloat = 12.0
myfloat
type(myfloat)
# Out:
# float

# %%
myfloat2 = float(12)
myfloat2
type(myfloat2)
# Out:
# float

# %% [markdown]
# #### complex

# %%
mycomp = complex(2,3)
mycomp
# Out:
# (2+3j)

# %%
j = 2

sum([2,4])
# Out:
# 6

# %%
(2+3j)
# Out:
# 8

# %%
complex(25,30)
# Out:
# (25+30j)

# %% [markdown]
# #### boolean

# %%
mybool1 = True
mybool2 = False

mybool1+mybool2
# Out:
# 1

# %% [markdown]
# ### Non Numeric

# %% [markdown]
# #### text

# %%
mytext1 = 'ama'
mytext1
mytext2 = '2'
mytext2
type(mytext2)
mytext3 = ama
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       4 mytext2
#       5 type(mytext2)
# ----> 6 mytext3 = ama
#
# NameError: name 'ama' is not defined

# %% [markdown]
# ### Sequences

# %% [markdown]
# #### list

# %%
mylist = [12,13,14,1,5]
mylist
# Out:
# [12, 13, 14, 1, 5]

# %% [markdown]
# ### tuple

# %%
mytuple = ("12" ,"32")
mytuple
# Out:
# ('12', '32')

# %% [markdown]
# #### range

# %%
### syntax
### range(start,stop,step)

# %%
list(range(1,10,3))
# Out:
# [1, 4, 7]

# %%
list(range(1,10,1))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### Mapping

# %% [markdown]
# #### Dictionary

# %%
#### syntax
#### {'key1':value1,'key2':value2,...........}

# %%
mydiction = {'surname':'Nyame','first name':'Vida','age':23,'tall':False}
mydiction
# Out:
# {'surname': 'Nyame', 'first name': 'Vida', 'age': 23, 'tall': False}

# %%
mydiction['tall']
# Out:
# False

# %% [markdown]
# sets

# %%
### {value1,value2,....}

# %%
myfruits = {'pineapple','banana','orange','berries','grapes','watermelon'}

# %%
myfruits
# Out:
# {'banana', 'berries', 'grapes', 'orange', 'pineapple', 'watermelon'}

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sum()
#
# TypeError: sum() takes at least 1 positional argument (0 given)

# %%
complex(3,5)
# Out:
# (3+5j)
