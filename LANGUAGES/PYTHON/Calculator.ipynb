# %%
import numpy as np

# %%
from numpy import sqrt

# %%
round((1/10)*sqrt(100-65),6)
# Out:
# 0.591608

# %%
(1/10)*sqrt(100-75)
# Out:
# 0.5

# %% [markdown]
# **$$n = \frac{Z^2_{\alpha/2} \times p(1-p)}{ME^2}$$**
