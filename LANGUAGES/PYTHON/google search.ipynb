# %% [markdown]
# pip install google(in the terminal)
# from googlesearch import search
# query = input("Enter your query: ")
# for i in searc(query, tld="com", num=10, stop=10, pause=2):
#     print(i)

# %%
from googlesearch import search
query = input("Enter your query: ")
for i in search(query, tld="com", num=10, stop=10, pause=2):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from googlesearch import search
#       2 query = input("Enter your query: ")
#       3 for i in search(query, tld="com", num=10, stop=10, pause=2):
#
# ModuleNotFoundError: No module named 'googlesearch'
