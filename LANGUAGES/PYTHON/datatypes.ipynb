# %%
myint = 20
myfloat = 20.0
mycomplex = 20 + 12j
mybool1 = True; mybool2 = False
mystr = "This is a Python string"
mylist = ["a", 1, 2, 3.5, 20 + 12j]
mytuple = ("a", 1, 2, 3.5, 20 + 12j)
myset = {"a", 1, 2, 3.5, 20 + 12j}
mydict = {"Course":"Math220", "Credit":3}
myint = None

# %%
myval=complex(1,3)
proops={"Real":myval.real,"Imaginary":myval.imag,"Conjugate":myval.conjugate(),"Magnitude":abs(myval)}
print('proops :', proops), print('myval :', myval)
# Out:
# proops : {'Real': 1.0, 'Imaginary': 3.0, 'Conjugate': (1-3j), 'Magnitude': 3.1622776601683795}
# myval : (1+3j)
# (None, None)

# %%
mydic = {'mtn':'024','Tigo':'027','Voda':'026'}
mydic.keys()
print(mydic.values())
# Out:
# dict_values(['024', '027', '026'])
