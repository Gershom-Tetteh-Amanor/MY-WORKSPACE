# %%
a = 0
for i in range(10):
    if i%2 == 0:
        a += i/2
    else:
        a += i
a
# Out:
# 35.0

# %%
a = (4,1)
b = (1,5)
c = 0
for i in range(2):
    c += (a[i]-b[i])**2
c**0.5
# Out:
# 5.0

# %%
a = 2 + 3j
a_new = a + a.conjugate()
if a_new.imag ==  0:
    a_new = a_new.real
a_new
# Out:
# 4.0

# %%
a = 'This is a not a new course'
res = []
for i in [0,1,5,10,16,17,23]:
    res.append(a[i])
''.join(res)
# Out:
# 'Thinner'

# %%
mystr = 'step on no pets'
res = ''
for i in mystr:
    if i.isalpha():
        res += i
res == res[::-1]
# Out:
# True

# %%
from cmath import e,pi,sin,cos
#s = [0,pi,2*pi,3*pi,4*pi,5*pi]
s = [0,1,2,3,4,5]
for i in s:
    z = e**(i*1j)
    #z.conjugate()
    print('when  z is', z, 'the magnitude is ','z.magnitude()')
z
# Out:
# when  z is (1+0j) the magnitude is  z.magnitude()
# when  z is (0.5403023058681398+0.8414709848078965j) the magnitude is  z.magnitude()
# when  z is (-0.4161468365471424+0.9092974268256817j) the magnitude is  z.magnitude()
# when  z is (-0.9899924966004454+0.1411200080598672j) the magnitude is  z.magnitude()
# when  z is (-0.6536436208636119-0.7568024953079282j) the magnitude is  z.magnitude()
# when  z is (0.28366218546322625-0.9589242746631385j) the magnitude is  z.magnitude()
# (0.28366218546322625-0.9589242746631385j)
