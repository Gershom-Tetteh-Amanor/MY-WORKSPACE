# %% [markdown]
# SECTION A --- BASIC THINGS

# %% [markdown]
# **SECTION A --- BASIC THINGS**

# %%
# COMMENTS
# ROLE OF DOUBLE QOUTE
print("ama")
# Out:
# ama

# %%
# role of single quote
print('ama')
# Out:
# ama

# %%
# role of the triple quote
print('''ama
      kofi
      yaa
      yaw''')
# Out:
# ama
#       kofi
#       yaa
#       yaw

# %%
print("ABC")
# Out:
# ABC

# %% [markdown]
# MODULES AND PIP-CONDA

# %%
import os 
# conects your directory

# %%
print(os.listdir()) # geting the files in the working directory
# Out:
# ['.ipynb_checkpoints', 'ACTUARIAL SENSE', 'Actuarial sense.ipynb', 'Anagornal.ipynb', 'Array indexing and slicing.ipynb', 'ASSIGGNMENT 4.ipynb', 'ASSIGGNMENT 4.py', 'ASSIGNMENT 5.ipynb', 'ASSIGNMENT 5.py', 'ASSIGNMENT II.ipynb', 'Assignment1 (feb 2022).ipynb', 'Assignment1.ipynb', 'Assignment2(feb 2022.ipynb', 'Assignment3 (10967696).ipynb', 'Assignment3(feb 2022).ipynb', 'Assignment3.ipynb', 'Assignment_1.ipynb', 'Assignment_2 (10967696).ipynb', 'Assignment_2.ipynb', 'Broadcasting.ipynb', 'Calculator.ipynb', 'calender.ipynb', 'datatypes.ipynb', 'Decisions.ipynb', 'factors.ipynb', 'Functions.ipynb', 'google search.ipynb', 'gpt.ipynb', 'kofi.ipynb', 'Lambda function.ipynb', 'List comprehension.ipynb', 'loop.ipynb', 'Map function.ipynb', 'MATH 220_2021(Solution).ipynb', 'MATH 220_2022.ipynb', 'Mathematical operations.ipynb', 'Matplotlib plotting.ipynb', 'MATRIX OPERATIONS.ipynb', 'newproject.py', 'Notebook 1.ipynb', 'Numpy.ipynb', 'Prime Numbers.ipynb', 'Problem set 1.ipynb', 'project.
# ...

# %% [markdown]
# INSTALLING NEW MODULE
# - use the anaconda command prompt
# - type ** 'conda install name_of_module' ** (eg. pandas)

# %%
# using conda instal
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # using conda instal
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# you can use pipo install

# %% [markdown]
# ** BASIC DATA TYPES **

# %%
a = "Annuity"
b = 10000
c = 90.2
d = True
e = None

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# float

# %%
type(d)
# Out:
# bool

# %%
type(e)
# Out:
# NoneType
