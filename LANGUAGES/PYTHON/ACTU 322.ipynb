# %% [markdown]
# we know that  $_{n}E_x= \frac{D_{x+n}}{D_x}$
# ```
# ```
# this implies that $_{n+m}E_x= \frac{D_{x+n+m}}{D_x}$--------------(a)
#
# Now considering the rhs of equation (6),
# ```
# ```
# $_{n}E_{x+m}. _{m}E_x = (\frac{D_{x+m+n}}{D_{x+m}})(\frac{D_{x+m}}{D_x})$
# ```
# ```
# $  = ({D_{x+m+n}})(\frac{1}{D_x})$
# ```
# ```
#  $=  \frac{D_{x+n+m}}{D_x}$
#  ```
#  ```
#  $= _{n+m}E_x$

# %% [markdown]
# $$^2(IA)^{ 1}_{x:\angl{n}} = ^2(IA)_{x}-^2_{n}E_{x}^2(IA)_{x+n}-({n^2}) ^2_{n}E_{X}^2A_{x+n}$$
# $$= ^2(IA)_{x}-V^n_{n}E_{x}^2(IA)_{x+n}-({n^2}).V^n_{n}E_{X}^2A_{x+n}$$
