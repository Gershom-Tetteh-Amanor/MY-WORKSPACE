# %% [markdown]
# # LAMBDA OR ANONYMOUS FUNCTIONS

# %% [raw]
# a). Create a function that calculates e^(-x^2).sin(x)
# b). Write a function that takes two lists/sets and determines if one is a subset of the other.
# c). Write a function for finding the determinant of a 2 x 2 matrix
# A =[a b
#    c d]

# %%
# solution (a)
from math import exp, sin
print(lambda x: (exp(-x**2))*(sin(x)),2)
# Out:
# <function <lambda> at 0x000001A165C79000> 2

# %%
# my own function
def expine(x):
    from math import exp,sin
    f = (exp(-x**2))*sin(x)
    return(f)
expine(1)
# Out:
# 0.3095598756531122

# %%
# solution (b)
lambda A,B: A<=B or B<=A
# Out:
# <function __main__.<lambda>(A, B)>

# %%
# Not correct
# my own function to do it 
def g(A,B):
    check = ((A <= B) or (B <= A))
    if check== True:
        if A<B:
            print(A, ' is a subset of ', B)
        elif A==B:
            print(A, " is a proper subset of ", B)
        else:    
            print(B, 'is a subset of ', A)
    else:
        print(A, " and ", B, "are not ", "subsets of each other")
    return(None)


A = {1,2,3,4,5,6,7,8,9}
B = {1,2,3,4,5,6,7,8,9}
g(A,B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}  is a proper subset of  {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
# solution (c)
lambda a,b,c,d : a*c-b*d
# Out:
# <function __main__.<lambda>(a, b, c, d)>

# %%
def det(a,b,c,d):
    d = a*c-b*d
    return(d)

A=[1,2,3,4]
det(1,2,3,4)
# Out:
# -5

# %% [markdown]
# # class codes

# %%
def f(x,y):
    return(x**2 + 2*y)
F=f
F(2,4)
# Out:
# 12

# %%
lambda x,y: x**2 + 2*y
# Out:
# <function __main__.<lambda>(x, y)>

# %%
(lambda x,y: x**2 + 2*y)(2,4)
# Out:
# 12

# %%
def h(x,F):
    res = []
    for i in x:
        res.append(F(i))
    return(res)
h

# %%
h([2,3,4,5],(lambda x: x**2 + 2*x))
# Out:
# [8, 15, 24, 35]
