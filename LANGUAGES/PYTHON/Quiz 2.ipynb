# %%
s = 'This is my class'
s = s[:2]+'at'+s[4:]
s

# %%
x = [3,4,8,9,13,12,15]
x = [x[i]-x[i-1] for i in range(1,len(x))]
x = all([i>0 for i in x])
x
# Out:
# False

# %%
a = 75
g = ['F','E','D','C','B','A']
res = (min(max(a,40),90)-40)/10
res = int(res)
grade = g[res]
grade

# %%
import numpy as np
x = np.array([1,2,3,4])
y = x**2 + 2*x +1
y

# %%
b = 0
for i in range(5):
    b += i**2/10
b

# %%
y = [i if i%3==0 else i**2 for i in range(1,7)]
print(y)
# Out:
# [1, 4, 3, 16, 25, 6]

# %%
# [exp (cond) else exp for i in range]

# %%
x = [4,-7,23,-54,39,40,-1,11]
m = x[0]
for i in x:
    if abs(i) < m:
        m = abs(i)
m

# %%
def quadx(x):
    a = x**2 + 2*x +1
    return a
quadx(5)

# %%
import numpy as np
a = np.arange(2,7,1.0)
b = np.linspace(6,2,5)
a+b
a
# Out:
# array([2., 3., 4., 5., 6.])

# %%
import numpy as np
x = np.linspace(0,1,5)
y = x**2
d = (y[1:] - y[:-1])/(x[1]-x[0])
d
# Out:
# array([0.25, 0.75, 1.25, 1.75])
